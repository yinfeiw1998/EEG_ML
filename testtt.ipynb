# %%
import features
file_name = 'test.txt'
# learned_data = features.features('101/101')

# s = 60000
# for i in range(720):
#     learned_data.extract_features(101, s, s+1000, file_name)
#     print("101", " finished ", i)
#     s += 1000
    
# learned_data = features.features('102/102')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(102, s, s+1000, file_name)
#     print("102", " finished ", i)
#     s += 1000

# learned_data = features.features('153/153')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(153, s, s+1000, file_name)
#     print("153", " finished ", i)
#     s += 1000

# %%
learned_data = features.features('208/208')
s = 60000
for i in range(720):
    learned_data.extract_features(208, s, s+1000, file_name)
    print("208", " finished ", i)
    s += 1000

# learned_data = features.features('244/244')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(244, s, s+1000, file_name)
#     print("244", " finished ", i)
#     s += 1000


# learned_data = features.features('245/245')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(245, s, s+1000, file_name)
#     print("245", " finished ", i)
#     s += 1000
# Out:
# Extracting EDF parameters from /Users/yinfeiwang/Desktop/EECS199/Human_data/208/208.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4789599  =      0.000 ... 23947.995 secs...
# 208  finished  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ab26b7d17dfc> in <module>
#       2 s = 60000
#       3 for i in range(720):
# ----> 4     learned_data.extract_features(208, s, s+1000, file_name)
#       5     print("208", " finished ", i)
#       6     s += 1000
#
# ~/Desktop/EECS199/EEG_bio_metrics/features.py in extract_features(self, user_id, start, end, file_name)
#     187         #print("Approximate Entropy\n")
#     188         for i in range(len(self.channel)):
# --> 189             self.ApprEnt.append(ApEn(self.raw_control[i], 2, 3))
# ...

# %%
file_name = 'startFrom5Minutes_noOverlap_720'
for i in range(2, 3252):
    f_object = open(file_name+" "+str(i)+'.txt', "r")
    temp = f_object.readline()
    f_object.close()
    f_object = open(file_name+'.txt', "a")
    f_object.write(temp)
    f_object.close()

# %%
# learned_data = features.features('340/340')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(340, s, s+1000, file_name)
#     print("340", " finished ", i)
#     s += 1000
    
# learned_data = features.features('399/399')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(399, s, s+1000, file_name)
#     print("399", " finished ", i)
#     s += 1000
    
# learned_data = features.features('424/424')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(424, s, s+1000, file_name)
#     print("424", " finished ", i)
#     s += 1000

# %%
# learned_data = features.features('440/440')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(440, s, s+1000, file_name)
#     print("440", " finished ", i)
#     s += 1000
    
# learned_data = features.features('457/457')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(457, s, s+1000, file_name)
#     print("457", " finished ", i)
#     s += 1000
    
# learned_data = features.features('488/488')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(488, s, s+1000, file_name)
#     print("488", " finished ", i)
#     s += 1000
    
# learned_data = features.features('495/495')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(495, s, s+1000, file_name)
#     print("495", " finished ", i)
#     s += 1000
    
# learned_data = features.features('510/510')
# s = 60000 + 500*1000
# for i in range(720):
#     learned_data.extract_features(510, s, s+1000, file_name)
#     print("510", " finished ", i)
#     s += 1000
    
# learned_data = features.features('556_1/556_1')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(556, s, s+1000, file_name)
#     print("556", " finished ", i)
#     s += 1000
    
# learned_data = features.features('563/563')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(563, s, s+1000, file_name)
#     print("563", " finished ", i)
#     s += 1000

# learned_data = features.features('603/603')
# s = 60000+599*1000
# for i in range(121):
#     learned_data.extract_features(603, s, s+1000, file_name)
#     print("603", " finished ", i)
#     s += 1000 

# learned_data = features.features('610/610')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(610, s, s+1000, file_name)
#     print("610", " finished ", i)
#     s += 1000
    
# learned_data = features.features('670/670')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(670, s, s+1000, file_name)
#     print("670", " finished ", i)
#     s += 1000
    
# learned_data = features.features('744/744')
# s = 60000
# for i in range(720):
#     learned_data.extract_features(744, s, s+1000, file_name)
#     print("744", " finished ", i)
#     s += 1000
